# %%
import pandas as pd
import numpy as np

# %%
houses = pd.read_csv('./properties.csv')

# %%
houses.head()
# Out:
#    Unnamed: 0                           Address           AreaName  Price ($)  \
# 0           0       86 Waterford Dr Toronto, ON           Richview     999888
# 1           1  #80 - 100 BEDDOE DR Hamilton, ON     Chedoke Park B     399900
# 2           2    213 Bowman Street Hamilton, ON  Ainslie Wood East     479000
# 3           3      102 NEIL Avenue Hamilton, ON          Greenford     285900
# 4           6   #1409 - 230 King St Toronto, ON           Downtown     362000
#
#          lat        lng
# 0  43.679882 -79.544266
# 1  43.250000 -79.904396
# 2  43.251690 -79.919357
# 3  43.227161 -79.767403
# 4  43.651478 -79.368118

# %%
houses.rename(columns = {'Unnamed: 0':'id','Address':'address','AreaName':'area_name','Price ($)':'price','lat':'latitude','lng':'longitude'},inplace=True)

# %%
houses.head()
# Out:
#    id                           address          area_name   price   latitude  \
# 0   0       86 Waterford Dr Toronto, ON           Richview  999888  43.679882
# 1   1  #80 - 100 BEDDOE DR Hamilton, ON     Chedoke Park B  399900  43.250000
# 2   2    213 Bowman Street Hamilton, ON  Ainslie Wood East  479000  43.251690
# 3   3      102 NEIL Avenue Hamilton, ON          Greenford  285900  43.227161
# 4   6   #1409 - 230 King St Toronto, ON           Downtown  362000  43.651478
#
#    longitude
# 0 -79.544266
# 1 -79.904396
# 2 -79.919357
# 3 -79.767403
# 4 -79.368118

# %%
houses.set_index('id',inplace=True)

# %%
houses.index.name = None
houses.head()
# Out:
#                             address          area_name   price   latitude  \
# 0       86 Waterford Dr Toronto, ON           Richview  999888  43.679882
# 1  #80 - 100 BEDDOE DR Hamilton, ON     Chedoke Park B  399900  43.250000
# 2    213 Bowman Street Hamilton, ON  Ainslie Wood East  479000  43.251690
# 3      102 NEIL Avenue Hamilton, ON          Greenford  285900  43.227161
# 6   #1409 - 230 King St Toronto, ON           Downtown  362000  43.651478
#
#    longitude
# 0 -79.544266
# 1 -79.904396
# 2 -79.919357
# 3 -79.767403
# 6 -79.368118

# %%
houses.describe()
# Out:
#               price      latitude     longitude
# count  2.535100e+04  25351.000000  25351.000000
# mean   5.645438e+05     37.326614    -85.218379
# std    8.475962e+05     82.858347     73.093572
# min    0.000000e+00   -999.000000   -999.000000
# 25%    2.199000e+05     43.401087    -80.308159
# 50%    3.719000e+05     43.715977    -79.503342
# 75%    6.199000e+05     44.466711    -79.107326
# max    3.250000e+07     53.851017      1.074519

# %%
houses.dtypes
# Out:
# address       object
# area_name     object
# price          int64
# latitude     float64
# longitude    float64
# dtype: object

# %%
houses.groupby('area_name').price.max()
# Out:
# area_name
# Aberfoyle                     68000
# Acton                        529000
# Agassiz                       74000
# Agincourt                   1658000
# Agincourt North             2200000
#                              ...
# York Mills                 14800000
# York University Heights     1500000
# Yorkdale                     178500
# Zephyr                      1999999
# Zurich                       227900
# Name: price, Length: 1119, dtype: int64

# %%
houses.groupby('area_name').price.agg(['min','max','mean'])
# Out:
#                              min       max          mean
# area_name
# Aberfoyle                  68000     68000  6.800000e+04
# Acton                     259000    529000  3.793000e+05
# Agassiz                    74000     74000  7.400000e+04
# Agincourt                     49   1658000  4.252873e+05
# Agincourt North          2200000   2200000  2.200000e+06
# ...                          ...       ...           ...
# York Mills                   145  14800000  4.436242e+06
# York University Heights      500   1500000  4.832300e+05
# Yorkdale                   69000    178500  1.208333e+05
# Zephyr                    499000   1999999  1.142386e+06
# Zurich                    227900    227900  2.279000e+05
#
# [1119 rows x 3 columns]

# %%
houses.isnull().sum()
# Out:
# address        0
# area_name    483
# price          0
# latitude       0
# longitude      0
# dtype: int64

# %%
houses[houses.area_name.isnull()]
# Out:
#                                             address area_name   price  \
# 269               7393 Wellington Rd 51 . Ariss, ON       NaN  699000
# 3004                120 WOODBURN Road Glanbrook, ON       NaN  329900
# 4089        457289 CONCESSION 8  S Sydenham Twp, ON       NaN  729900
# 4585                       152 MARR Drive Elora, ON       NaN  399900
# 4770    3058 Bruce Road 20 Other Bruce Township, ON       NaN  189900
# ...                                             ...       ...     ...
# 120763    823 English Settlement Rd Murray Ward, ON       NaN  699000
# 121479           3606 CEDAR GROVE ROAD Prescott, ON       NaN  399999
# 124645     7256 Wellington Road 124 Road Guelph, ON       NaN  499900
# 124649   7985 Tait`s Beach Rd Hamilton Township, ON       NaN  599000
# 124791    0 Cornish Hollow Rd Hamilton Township, ON       NaN  399500
#
#           latitude   longitude
# 269      43.596718  -80.340660
# 3004   -999.000000 -999.000000
# ...

# %%
houses.area_name.value_counts(dropna=False)
# Out:
# Downtown         830
# Mississauga      752
# NaN              483
# Waterloo         459
# Niagara Falls    355
#                 ...
# York District      1
# New Dundee         1
# Curve Lake         1
# Gogama             1
# Atwood             1
# Name: area_name, Length: 1120, dtype: int64

# %%
# Find the house with the lowest price and the house with the highest price
# in downtown area
houses[houses.area_name=='Downtown'].agg(['min','max'])
# Out:
#                                     address area_name     price   latitude  \
# min  # 2407 - 75 ST NICHOLAS ST Toronto, ON  Downtown         1  40.219128
# max                92 KING ST E Toronto, ON  Downtown  14500000  43.670547
#
#      longitude
# min -79.410561
# max -74.764900

# %%
houses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25351 entries, 0 to 124929
# Data columns (total 5 columns):
# address      25351 non-null object
# area_name    24868 non-null object
# price        25351 non-null int64
# latitude     25351 non-null float64
# longitude    25351 non-null float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 2.4+ MB

# %%
houses.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25351 entries, 0 to 124929
# Data columns (total 5 columns):
# address      25351 non-null object
# area_name    24868 non-null object
# price        25351 non-null int64
# latitude     25351 non-null float64
# longitude    25351 non-null float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 5.9 MB

# %%
len(houses.area_name.unique())
# Out:
# 1120

# %%
# Out:
#                                              address                area_name  \
# 0                        86 Waterford Dr Toronto, ON                 Richview
# 1                   #80 - 100 BEDDOE DR Hamilton, ON           Chedoke Park B
# 2                     213 Bowman Street Hamilton, ON        Ainslie Wood East
# 3                       102 NEIL Avenue Hamilton, ON                Greenford
# 6                    #1409 - 230 King St Toronto, ON                 Downtown
# ...                                              ...                      ...
# 124922       3100 CARLING AVENUE UNIT#416 Ottawa, ON                 Bayshore
# 124924              5827 GLADEWOODS PLACE Ottawa, ON                  Orléans
# 124925              6349 DEERMEADOW DRIVE Ottawa, ON                   Greely
# 124928                     212 ALVIN ROAD Ottawa, ON  Rockcliffe - Manor Park
# 124929  BARTON Street BARTON Street Stoney Creek, ON             Stoney Creek
#
# ...

# %%
houses.dropna(how='any').shape
# Out:
# (24868, 5)

# %%
houses['area_name'].fillna(value='UNDEFINED',inplace=True)

# %%
houses[houses['area_name']=='UNDEFINED'].area_name
# Out:
# 269       UNDEFINED
# 3004      UNDEFINED
# 4089      UNDEFINED
# 4585      UNDEFINED
# 4770      UNDEFINED
#             ...
# 120763    UNDEFINED
# 121479    UNDEFINED
# 124645    UNDEFINED
# 124649    UNDEFINED
# 124791    UNDEFINED
# Name: area_name, Length: 483, dtype: object

# %%
# Deal with duplicated columns
houses.duplicated().sum()
# Out:
# 949

# %%
# examine duplicated columns
houses.loc[houses.duplicated(keep=False),:]
# Out:
#                                         address         area_name    price  \
# 51                   61 Mayland Tr Hamilton, ON          Hamilton   399900
# 61                  15 JOHN Street Hamilton, ON  Central Hamilton        0
# 62                  15 JOHN Street Hamilton, ON  Central Hamilton        0
# 239                   47 Edgehill Dr Guelph, ON   Exhibition Park   439900
# 243                96 Silurian Drive Guelph, ON  Grange Hill East   387900
# ...                                         ...               ...      ...
# 124809             677 KING Street Hamilton, ON          Hamilton        0
# 124819          618 Erbsville Road Waterloo, ON        Laurelwood  1015000
# 124852  35 SOUTHSHORE Crescent Stoney Creek, ON      Stoney Creek        0
# 124876       131 BRIDGEPORT Road E Waterloo, ON          Waterloo   450000
# 124906         156 PARKDALE Avenue Hamilton, ON       Normanhurst        0
#
#          latitude  longitude
# 51      43.190010 -79.774529
# ...

# %%
houses.drop_duplicates(keep=False).shape
# Out:
# (23545, 5)

# %%
houses.drop_duplicates(keep='first',inplace=True)

# %%
# Test if function works properly
houses.duplicated().sum()
# Out:
# 0

# %%
houses.dtypes
# Out:
# address       object
# area_name     object
# price          int64
# latitude     float64
# longitude    float64
# dtype: object

# %%
houses['address'] = houses['address'].astype('str')

# %%
houses.dtypes
# Out:
# address       object
# area_name     object
# price          int64
# latitude     float64
# longitude    float64
# dtype: object

# %%
houses['address'].str.replace('"','').tail()
# Out:
# 124922    nan
# 124924    nan
# 124925    nan
# 124928    nan
# 124929    nan
# Name: address, dtype: object

# %%
## Visualization part 1

# %%
cleaned_houses = pd.read_csv('houses.csv')

# %%
cleaned_houses.tail(10)
# Out:
#            id                                       address  \
# 24392  124916                11766 RIVERSIDE  E Windsor, ON
# 24393  124917               403 ANDERSON DRIVE Cornwall, ON
# 24394  124918            LOT 7 Pauline Tom Ave Kingston, ON
# 24395  124919    4182 THOMAS ALTON Boulevard Burlington, ON
# 24396  124921              397 PHOENIX CRESCENT Orleans, ON
# 24397  124922       3100 CARLING AVENUE UNIT#416 Ottawa, ON
# 24398  124924              5827 GLADEWOODS PLACE Ottawa, ON
# 24399  124925              6349 DEERMEADOW DRIVE Ottawa, ON
# 24400  124928                     212 ALVIN ROAD Ottawa, ON
# 24401  124929  BARTON Street BARTON Street Stoney Creek, ON
#
#                      area_name    price   latitude  longitude
# 24392           East Riverside   699900  42.333740 -82.900284
# 24393                 Cornwall   204900  45.031879 -74.692535
# 24394                 Kingston   799900  44.275501 -76.444443
# ...

# %%
cleaned_houses['address'] = cleaned_houses['address'].astype('str')

# %%
cleaned_houses.dtypes
# Out:
# Unnamed: 0      int64
# address        object
# area_name      object
# price           int64
# latitude      float64
# longitude     float64
# dtype: object

# %%
cleaned_house=pd.read_csv('./houses.csv')

# %%
cleaned_house.head()
# Out:
#    Unnamed: 0                           address          area_name   price  \
# 0           0       86 Waterford Dr Toronto, ON           Richview  999888
# 1           1  #80 - 100 BEDDOE DR Hamilton, ON     Chedoke Park B  399900
# 2           2    213 Bowman Street Hamilton, ON  Ainslie Wood East  479000
# 3           3      102 NEIL Avenue Hamilton, ON          Greenford  285900
# 4           6   #1409 - 230 King St Toronto, ON           Downtown  362000
#
#     latitude  longitude
# 0  43.679882 -79.544266
# 1  43.250000 -79.904396
# 2  43.251690 -79.919357
# 3  43.227161 -79.767403
# 4  43.651478 -79.368118

# %%
cleaned_house.rename(columns = {'Unnamed: 0':'id'},inplace=True)

# %%
cleaned_house.head()
# Out:
#    id                           address          area_name   price   latitude  \
# 0   0       86 Waterford Dr Toronto, ON           Richview  999888  43.679882
# 1   1  #80 - 100 BEDDOE DR Hamilton, ON     Chedoke Park B  399900  43.250000
# 2   2    213 Bowman Street Hamilton, ON  Ainslie Wood East  479000  43.251690
# 3   3      102 NEIL Avenue Hamilton, ON          Greenford  285900  43.227161
# 4   6   #1409 - 230 King St Toronto, ON           Downtown  362000  43.651478
#
#    longitude
# 0 -79.544266
# 1 -79.904396
# 2 -79.919357
# 3 -79.767403
# 4 -79.368118

# %%
cleaned_house.set_index('id',inplace=True)

# %%
cleaned_house.head()
# Out:
#                              address          area_name   price   latitude  \
# id
# 0        86 Waterford Dr Toronto, ON           Richview  999888  43.679882
# 1   #80 - 100 BEDDOE DR Hamilton, ON     Chedoke Park B  399900  43.250000
# 2     213 Bowman Street Hamilton, ON  Ainslie Wood East  479000  43.251690
# 3       102 NEIL Avenue Hamilton, ON          Greenford  285900  43.227161
# 6    #1409 - 230 King St Toronto, ON           Downtown  362000  43.651478
#
#     longitude
# id
# 0  -79.544266
# 1  -79.904396
# 2  -79.919357
# 3  -79.767403
# 6  -79.368118

# %%
# Export data for visualization using deck.gl and google map API
cleaned_house.to_csv('houses.csv')

# %%
cleaned_house['address']=cleaned_house.address.str.strip()

# %%
cleaned_house.to_csv('test.csv')

# %%
cleaned_house["address"]=cleaned_house.address.str.replace('[\"\"]', '')

# %%
cleaned_house.to_csv('test.csv')

# %%
cleaned_houses.head()
# Out:
#    id                           address          area_name   price   latitude  \
# 0   0       86 Waterford Dr Toronto, ON           Richview  999888  43.679882
# 1   1  #80 - 100 BEDDOE DR Hamilton, ON     Chedoke Park B  399900  43.250000
# 2   2    213 Bowman Street Hamilton, ON  Ainslie Wood East  479000  43.251690
# 3   3      102 NEIL Avenue Hamilton, ON          Greenford  285900  43.227161
# 4   6   #1409 - 230 King St Toronto, ON           Downtown  362000  43.651478
#
#    longitude
# 0 -79.544266
# 1 -79.904396
# 2 -79.919357
# 3 -79.767403
# 4 -79.368118

# %%
cleaned_houses['type_of_house'] = 'UNDEFINED'

# %%
cleaned_houses.head()
# Out:
#    id                           address          area_name   price   latitude  \
# 0   0       86 Waterford Dr Toronto, ON           Richview  999888  43.679882
# 1   1  #80 - 100 BEDDOE DR Hamilton, ON     Chedoke Park B  399900  43.250000
# 2   2    213 Bowman Street Hamilton, ON  Ainslie Wood East  479000  43.251690
# 3   3      102 NEIL Avenue Hamilton, ON          Greenford  285900  43.227161
# 4   6   #1409 - 230 King St Toronto, ON           Downtown  362000  43.651478
#
#    longitude type_of_house
# 0 -79.544266     UNDEFINED
# 1 -79.904396     UNDEFINED
# 2 -79.919357     UNDEFINED
# 3 -79.767403     UNDEFINED
# 4 -79.368118     UNDEFINED

# %%
cleaned_houses.columns
# Out:
# Index(['id', 'address', 'area_name', 'price', 'latitude', 'longitude'], dtype='object')

# %%
cleaned_houses[cleaned_houses.address.str.contains('#')]
# Out:
#            id                                   address         area_name  \
# 1           1          #80 - 100 BEDDOE DR Hamilton, ON    Chedoke Park B
# 4           6           #1409 - 230 King St Toronto, ON          Downtown
# 13         21   #808 - 2167 Lake Shore Blvd Toronto, ON          Parkdale
# 14         22  #2706 - 2167 Lake Shore Blvd Toronto, ON          Parkdale
# 15         23            #710 - 1080 Bay St Toronto, ON          Downtown
# ...       ...                                       ...               ...
# 24377  124898       #Ph#12 - 125 Wilson St Hamilton, ON  Central Hamilton
# 24379  124901          #209 - 1291 GORDON ST Guelph, ON            Guelph
# 24382  124904       #504 - 111 FORSYTHE ST Oakville, ON          Oakville
# 24386  124909          #326 - 1291 GORDON ST Guelph, ON            Guelph
# 24397  124922   3100 CARLING AVENUE UNIT#416 Ottawa, ON          Bayshore
#
#          price   latitude  longitude
# 1       399900  43.250000 -79.904396
# ...

# %%
cleaned_houses['type_of_house'] = cleaned_houses[cleaned_houses.address.str.contains('#')].address

# %%
cleaned_houses.fillna('House',inplace=True)

# %%
cleaned_houses.head(10)
# Out:
#    id                                  address          area_name    price  \
# 0   0              86 Waterford Dr Toronto, ON           Richview   999888
# 1   1         #80 - 100 BEDDOE DR Hamilton, ON     Chedoke Park B   399900
# 2   2           213 Bowman Street Hamilton, ON  Ainslie Wood East   479000
# 3   3             102 NEIL Avenue Hamilton, ON          Greenford   285900
# 4   6          #1409 - 230 King St Toronto, ON           Downtown   362000
# 5   7        254A Monarch Park Ave Toronto, ON      Old East York  1488000
# 6   8             532 Caledonia Rd Toronto, ON           Fairbank       25
# 7   9           11 REBECCA Street Hamilton, ON   Central Hamilton   254900
# 8  10         617 BRIGADOON Drive Hamilton, ON            Gourley   364900
# 9  12  51 - 255 MOUNT ALBION Road Hamilton, ON           Red Hill   304900
#
#     latitude  longitude                     type_of_house
# 0  43.679882 -79.544266                             House
# ...

# %%
cleaned_houses[cleaned_houses.type_of_house != 'House'].type_of_house = "Condo/Apartment"
# Out:
# /opt/anaconda/lib/python3.7/site-packages/pandas/core/generic.py:5208: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
cleaned_houses.loc[:,'type_of_house'] == 'House'
# Out:
# 0         True
# 1        False
# 2         True
# 3         True
# 4        False
#          ...
# 24397    False
# 24398     True
# 24399     True
# 24400     True
# 24401     True
# Name: type_of_house, Length: 24402, dtype: bool

# %%
cleaned_houses.head()
# Out:
#    id                           address          area_name   price   latitude  \
# 0   0       86 Waterford Dr Toronto, ON           Richview  999888  43.679882
# 1   1  #80 - 100 BEDDOE DR Hamilton, ON     Chedoke Park B  399900  43.250000
# 2   2    213 Bowman Street Hamilton, ON  Ainslie Wood East  479000  43.251690
# 3   3      102 NEIL Avenue Hamilton, ON          Greenford  285900  43.227161
# 4   6   #1409 - 230 King St Toronto, ON           Downtown  362000  43.651478
#
#    longitude                     type_of_house
# 0 -79.544266                             House
# 1 -79.904396  #80 - 100 BEDDOE DR Hamilton, ON
# 2 -79.919357                             House
# 3 -79.767403                             House
# 4 -79.368118   #1409 - 230 King St Toronto, ON

# %%
cleaned_houses[~(cleaned_houses['type_of_house'].str.contains("House"))]
# Out:
#            id                                   address         area_name  \
# 1           1          #80 - 100 BEDDOE DR Hamilton, ON    Chedoke Park B
# 4           6           #1409 - 230 King St Toronto, ON          Downtown
# 13         21   #808 - 2167 Lake Shore Blvd Toronto, ON          Parkdale
# 14         22  #2706 - 2167 Lake Shore Blvd Toronto, ON          Parkdale
# 15         23            #710 - 1080 Bay St Toronto, ON          Downtown
# ...       ...                                       ...               ...
# 24377  124898       #Ph#12 - 125 Wilson St Hamilton, ON  Central Hamilton
# 24379  124901          #209 - 1291 GORDON ST Guelph, ON            Guelph
# 24382  124904       #504 - 111 FORSYTHE ST Oakville, ON          Oakville
# 24386  124909          #326 - 1291 GORDON ST Guelph, ON            Guelph
# 24397  124922   3100 CARLING AVENUE UNIT#416 Ottawa, ON          Bayshore
#
#          price   latitude  longitude                             type_of_house
# ...

# %%
cleaned_houses.loc[cleaned_houses['type_of_house'] != 'House', 'type_of_house'] = "Condo/Apartment"

# %%
cleaned_houses.head()
# Out:
#    id                           address          area_name   price   latitude  \
# 0   0       86 Waterford Dr Toronto, ON           Richview  999888  43.679882
# 1   1  #80 - 100 BEDDOE DR Hamilton, ON     Chedoke Park B  399900  43.250000
# 2   2    213 Bowman Street Hamilton, ON  Ainslie Wood East  479000  43.251690
# 3   3      102 NEIL Avenue Hamilton, ON          Greenford  285900  43.227161
# 4   6   #1409 - 230 King St Toronto, ON           Downtown  362000  43.651478
#
#    longitude    type_of_house
# 0 -79.544266            House
# 1 -79.904396  Condo/Apartment
# 2 -79.919357            House
# 3 -79.767403            House
# 4 -79.368118  Condo/Apartment

# %%
cleaned_houses.head(20)
# Out:
#     id                                   address          area_name    price  \
# 0    0               86 Waterford Dr Toronto, ON           Richview   999888
# 1    1          #80 - 100 BEDDOE DR Hamilton, ON     Chedoke Park B   399900
# 2    2            213 Bowman Street Hamilton, ON  Ainslie Wood East   479000
# 3    3              102 NEIL Avenue Hamilton, ON          Greenford   285900
# 4    6           #1409 - 230 King St Toronto, ON           Downtown   362000
# 5    7         254A Monarch Park Ave Toronto, ON      Old East York  1488000
# 6    8              532 Caledonia Rd Toronto, ON           Fairbank       25
# 7    9            11 REBECCA Street Hamilton, ON   Central Hamilton   254900
# 8   10          617 BRIGADOON Drive Hamilton, ON            Gourley   364900
# 9   12   51 - 255 MOUNT ALBION Road Hamilton, ON           Red Hill   304900
# 10  13           1170 LAMBTON Drive Oakville, ON          Clearview  1289000
# ...

# %%
cleaned_houses.to_csv('houses.csv')
